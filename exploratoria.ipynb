# %%
#https://www.kaggle.com/code/ambrosm/pss4e5-eda-which-makes-sense/notebook

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load the data
df = pd.read_csv('train.csv')

# %%
df
# Out:
#               id  MonsoonIntensity  TopographyDrainage  RiverManagement  \
# 0              0                 5                   8                5
# 1              1                 6                   7                4
# 2              2                 6                   5                6
# 3              3                 3                   4                6
# 4              4                 5                   3                2
# ...          ...               ...                 ...              ...
# 1117952  1117952                 3                   3                4
# 1117953  1117953                 2                   2                4
# 1117954  1117954                 7                   3                9
# 1117955  1117955                 7                   3                3
# 1117956  1117956                 4                   5                6
#
#          Deforestation  Urbanization  ClimateChange  DamsQuality  Siltation  \
# 0                    8             6              4            4          3
# 1                    4             8              8            3          5
# 2                    7             3              7            1          5
# 3                    5             4              8            4          7
# 4                    6             4              4            3          3
# ...                ...           ...            ...          ...        ...
# 1117952             10             4              5            5          7
# 1117953              3             9              5            8          1
# 1117954              4             6              5            9          1
# 1117955              7             5              2            3          4
# 1117956              9             5              5            2          8
#
#          AgriculturalPractices  ...  DrainageSystems  CoastalVulnerability  \
# 0                            3  ...                5                     3
# 1                            4  ...                7                     2
# 2                            4  ...                7                     3
# 3                            6  ...                2                     4
# 4                            3  ...                2                     2
# ...                        ...  ...              ...                   ...
# 1117952                     10  ...                7                     8
# 1117953                      3  ...                9                     4
# 1117954                      3  ...                5                     5
# 1117955                      6  ...                6                     8
# 1117956                      4  ...                4                     8
#
#          Landslides  Watersheds  DeterioratingInfrastructure  PopulationScore  \
# 0                 3           5                            4                7
# 1                 0           3                            5                3
# 2                 7           5                            6                8
# 3                 7           4                            4                6
# 4                 6           6                            4                1
# ...             ...         ...                          ...              ...
# 1117952           7           2                            2                1
# 1117953           4           3                            7                4
# 1117954           5           5                            6                5
# 1117955           5           3                            4                6
# 1117956           6           5                            5                6
#
#          WetlandLoss  InadequatePlanning  PoliticalFactors  FloodProbability
# 0                  5                   7                 3             0.445
# 1                  3                   4                 3             0.450
# 2                  2                   3                 3             0.530
# 3                  5                   7                 5             0.535
# 4                  2                   3                 5             0.415
# ...              ...                 ...               ...               ...
# 1117952            4                   6                 4             0.495
# 1117953            9                   4                 5             0.480
# 1117954            5                   2                 4             0.485
# 1117955            7                   6                 4             0.495
# 1117956            7                   7                 8             0.560
#
# [1117957 rows x 22 columns]

# %%
# summary table function
pd.options.display.float_format = '{:,.2f}'.format
def summary(df):
    print(f'data shape: {df.shape}')
    summ = pd.DataFrame(df.dtypes, columns=['data type'])
    summ['#missing'] = df.isnull().sum().values 
    summ['%missing'] = df.isnull().sum().values / len(df) * 100
    summ['#unique'] = df.nunique().values
    desc = pd.DataFrame(df.describe(include='all').transpose())
    summ['min'] = desc['min'].values
    summ['max'] = desc['max'].values
    summ['average'] = desc['mean'].values
    summ['standard_deviation'] = desc['std'].values
    summ['first value'] = df.loc[0].values
    summ['second value'] = df.loc[1].values
    summ['third value'] = df.loc[2].values
    
    return summ

# %%
summary(df)
# Out:
# data shape: (1117957, 22)
#                                 data type  #missing  %missing  #unique  min  \
# id                                  int64         0      0.00  1117957 0.00
# MonsoonIntensity                    int64         0      0.00       17 0.00
# TopographyDrainage                  int64         0      0.00       19 0.00
# RiverManagement                     int64         0      0.00       17 0.00
# Deforestation                       int64         0      0.00       18 0.00
# Urbanization                        int64         0      0.00       18 0.00
# ClimateChange                       int64         0      0.00       18 0.00
# DamsQuality                         int64         0      0.00       17 0.00
# Siltation                           int64         0      0.00       17 0.00
# AgriculturalPractices               int64         0      0.00       17 0.00
# Encroachments                       int64         0      0.00       19 0.00
# IneffectiveDisasterPreparedness     int64         0      0.00       17 0.00
# DrainageSystems                     int64         0      0.00       18 0.00
# CoastalVulnerability                int64         0      0.00       18 0.00
# Landslides                          int64         0      0.00       17 0.00
# Watersheds                          int64         0      0.00       17 0.00
# DeterioratingInfrastructure         int64         0      0.00       18 0.00
# PopulationScore                     int64         0      0.00       19 0.00
# WetlandLoss                         int64         0      0.00       20 0.00
# InadequatePlanning                  int64         0      0.00       17 0.00
# PoliticalFactors                    int64         0      0.00       17 0.00
# FloodProbability                  float64         0      0.00       83 0.28
#
#                                          max    average  standard_deviation  \
# id                              1,117,956.00 558,978.00          322,726.53
# MonsoonIntensity                       16.00       4.92                2.06
# TopographyDrainage                     18.00       4.93                2.09
# RiverManagement                        16.00       4.96                2.07
# Deforestation                          17.00       4.94                2.05
# Urbanization                           17.00       4.94                2.08
# ClimateChange                          17.00       4.93                2.06
# DamsQuality                            16.00       4.96                2.08
# Siltation                              16.00       4.93                2.07
# AgriculturalPractices                  16.00       4.94                2.07
# Encroachments                          18.00       4.95                2.08
# IneffectiveDisasterPreparedness        16.00       4.95                2.08
# DrainageSystems                        17.00       4.95                2.07
# CoastalVulnerability                   17.00       4.95                2.09
# Landslides                             16.00       4.93                2.08
# Watersheds                             16.00       4.93                2.08
# DeterioratingInfrastructure            17.00       4.93                2.06
# PopulationScore                        18.00       4.93                2.07
# WetlandLoss                            19.00       4.95                2.07
# InadequatePlanning                     16.00       4.94                2.08
# PoliticalFactors                       16.00       4.94                2.09
# FloodProbability                        0.72       0.50                0.05
#
#                                  first value  second value  third value
# id                                      0.00          1.00         2.00
# MonsoonIntensity                        5.00          6.00         6.00
# TopographyDrainage                      8.00          7.00         5.00
# RiverManagement                         5.00          4.00         6.00
# Deforestation                           8.00          4.00         7.00
# Urbanization                            6.00          8.00         3.00
# ClimateChange                           4.00          8.00         7.00
# DamsQuality                             4.00          3.00         1.00
# Siltation                               3.00          5.00         5.00
# AgriculturalPractices                   3.00          4.00         4.00
# Encroachments                           4.00          6.00         5.00
# IneffectiveDisasterPreparedness         2.00          9.00         6.00
# DrainageSystems                         5.00          7.00         7.00
# CoastalVulnerability                    3.00          2.00         3.00
# Landslides                              3.00          0.00         7.00
# Watersheds                              5.00          3.00         5.00
# DeterioratingInfrastructure             4.00          5.00         6.00
# PopulationScore                         7.00          3.00         8.00
# WetlandLoss                             5.00          3.00         2.00
# InadequatePlanning                      7.00          4.00         3.00
# PoliticalFactors                        3.00          3.00         3.00
# FloodProbability                        0.45          0.45         0.53

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [id, MonsoonIntensity, TopographyDrainage, RiverManagement, Deforestation, Urbanization, ClimateChange, DamsQuality, Siltation, AgriculturalPractices, Encroachments, IneffectiveDisasterPreparedness, DrainageSystems, CoastalVulnerability, Landslides, Watersheds, DeterioratingInfrastructure, PopulationScore, WetlandLoss, InadequatePlanning, PoliticalFactors, FloodProbability]
# Index: []
#
# [0 rows x 22 columns]
